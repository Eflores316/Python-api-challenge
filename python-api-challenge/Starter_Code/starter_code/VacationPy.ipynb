# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("C:/users/fuent/Downloads/Starter_Code (14) - Copy/Starter_Code/output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID          City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  invercargill -46.4000  168.3500      2.79        82         100
# 1        1       iqaluit  63.7506  -68.5145      1.85        87          75
# 2        2        aykhal  66.0000  111.5000     17.06        48          77
# 3        3        vernon  50.2581 -119.2691     27.39        20          75
# 4        4     grytviken -54.2811  -36.5092     -9.57        75          17
#
#    Wind Speed Country        Date
# 0        2.68      NZ  2024-06-11
# 1        1.54      CA  2024-06-11
# 2        2.12      RU  2024-06-11
# 3        3.09      CA  2024-06-11
# 4        5.86      GS  2024-06-11

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot = city_data_df.hvplot.points("Lng", 
                                      "Lat", 
                                      geo = True,
                                      color = "City",
                                      alpha = 0.6,
                                      size = "Humidity",
                                      tiles = "OSM"
                                     )

# Display the map
map_plot
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
ideal_weather_df = city_data_df.loc[((city_data_df["Max Temp"] <= 30.0) & (city_data_df["Max Temp"] >= 20.0))\
                                 & (city_data_df["Cloudiness"] == 0),:]

# Drop any rows with null values
ideal_weather_df.dropna()

# Display sample data
ideal_weather_df
# Out:
#      City_ID                    City      Lat       Lng  Max Temp  Humidity  \
# 21        21          port elizabeth -33.9180   25.5701     22.28        58
# 32        32          guerrero negro  27.9769 -114.0611     21.21        60
# 34        34             sao vicente -23.9631  -46.3919     27.30        26
# 49        49                hamilton  39.1834  -84.5333     25.49        40
# 82        82           pacific grove  36.6177 -121.9166     29.66        78
# 108      108               el galpon -25.3807  -64.6526     20.80        68
# 113      113  hawaiian paradise park  19.5933 -154.9731     27.80        73
# 136      136            saint-pierre -21.3393   55.4781     22.82        73
# 146      146                  pierre  44.3683 -100.3510     29.51        36
# 216      216         remire-montjoly   4.9167  -52.2667     27.02        89
# 218      218                   sinop  41.7711   34.8709     21.62        27
# 248      248           joao pinheiro -17.7425  -46.1725     21.40        45
# 282      282         boiling springs  35.0465  -81.9818     29.92        40
# 289      289             tamanrasset  22.7850    5.5228     27.95         9
# 321      321           haiku-pauwela  20.9219 -156.3051     28.43        71
# 328      328                arequipa -16.3989  -71.5350     20.04        16
# 355      355                 badiyah  22.4500   58.8000     29.97        51
# 356      356           morehead city  34.7229  -76.7260     28.03        65
# 378      378              vila velha -20.3297  -40.2925     22.97        83
# 417      417             al kharijah  25.4514   30.5464     28.72        19
# 423      423                  sokcho  38.2083  128.5911     26.34        36
# 442      442             'ain benian  36.8028    2.9219     21.03        75
# 443      443           mermoz boabab  14.7065  -17.4758     26.31        83
# 512      512                 wacheng  33.7833  114.5167     29.39        48
# 519      519            stephenville  32.2207  -98.2023     28.41        72
# 537      537                 estevan  49.1334 -102.9842     26.23        38
# 549      549               nantucket  41.2835  -70.0995     20.01        76
# 556      556       steamboat springs  40.4850 -106.8317     27.41        25
# 560      560                  darwin -12.4611  130.8418     20.53        91
# 561      561                 chotila  22.4167   71.1833     27.47        71
# 577      577                    troy  42.6056  -83.1499     23.27        43
#
#      Cloudiness  Wind Speed Country        Date
# 21            0        2.06      ZA  2024-06-11
# 32            0        8.85      MX  2024-06-11
# 34            0        0.51      BR  2024-06-11
# 49            0        2.06      US  2024-06-11
# 82            0        3.58      US  2024-06-11
# 108           0        3.69      AR  2024-06-11
# 113           0        5.14      US  2024-06-11
# 136           0        2.06      RE  2024-06-11
# 146           0        1.79      US  2024-06-11
# 216           0        1.03      GF  2024-06-11
# 218           0        4.01      TR  2024-06-11
# 248           0        3.29      BR  2024-06-11
# 282           0        0.00      US  2024-06-11
# 289           0        3.09      DZ  2024-06-11
# 321           0       11.83      US  2024-06-11
# 328           0        2.57      PE  2024-06-11
# 355           0        3.02      OM  2024-06-11
# 356           0        5.14      US  2024-06-11
# 378           0        1.54      BR  2024-06-11
# 417           0        2.95      EG  2024-06-11
# 423           0        6.69      KR  2024-06-11
# 442           0        1.75      DZ  2024-06-11
# 443           0        4.12      SN  2024-06-11
# 512           0        2.90      CN  2024-06-11
# 519           0        1.54      US  2024-06-11
# 537           0        3.60      CA  2024-06-11
# 549           0        2.06      US  2024-06-11
# 556           0        4.63      US  2024-06-11
# 560           0        3.09      AU  2024-06-11
# 561           0        7.04      IN  2024-06-11
# 577           0        0.89      US  2024-06-11

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                        City Country      Lat       Lng  Humidity Hotel Name
# 21           port elizabeth      ZA -33.9180   25.5701        58
# 32           guerrero negro      MX  27.9769 -114.0611        60
# 34              sao vicente      BR -23.9631  -46.3919        26
# 49                 hamilton      US  39.1834  -84.5333        40
# 82            pacific grove      US  36.6177 -121.9166        78
# 108               el galpon      AR -25.3807  -64.6526        68
# 113  hawaiian paradise park      US  19.5933 -154.9731        73
# 136            saint-pierre      RE -21.3393   55.4781        73
# 146                  pierre      US  44.3683 -100.3510        36
# 216         remire-montjoly      GF   4.9167  -52.2667        89
# 218                   sinop      TR  41.7711   34.8709        27
# 248           joao pinheiro      BR -17.7425  -46.1725        45
# 282         boiling springs      US  35.0465  -81.9818        40
# 289             tamanrasset      DZ  22.7850    5.5228         9
# 321           haiku-pauwela      US  20.9219 -156.3051        71
# 328                arequipa      PE -16.3989  -71.5350        16
# 355                 badiyah      OM  22.4500   58.8000        51
# 356           morehead city      US  34.7229  -76.7260        65
# 378              vila velha      BR -20.3297  -40.2925        83
# 417             al kharijah      EG  25.4514   30.5464        19
# 423                  sokcho      KR  38.2083  128.5911        36
# 442             'ain benian      DZ  36.8028    2.9219        75
# 443           mermoz boabab      SN  14.7065  -17.4758        83
# 512                 wacheng      CN  33.7833  114.5167        48
# 519            stephenville      US  32.2207  -98.2023        72
# 537                 estevan      CA  49.1334 -102.9842        38
# 549               nantucket      US  41.2835  -70.0995        76
# 556       steamboat springs      US  40.4850 -106.8317        25
# 560                  darwin      AU -12.4611  130.8418        91
# 561                 chotila      IN  22.4167   71.1833        71
# 577                    troy      US  42.6056  -83.1499        43

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "apiKey":geoapify_key,
    "limit":10,
    "categories":"accommodation.hotel"
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat = row["Lat"]
    lon = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lon},{lat},{radius}"
    params["bias"] = f"proximity:{lon},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port elizabeth - nearest hotel: Waterford Hotel
# guerrero negro - nearest hotel: Plaza sal paraiso
# sao vicente - nearest hotel: Pousada Vitória
# hamilton - nearest hotel: North Vista Manor
# pacific grove - nearest hotel: Pacific Grove Inn
# el galpon - nearest hotel: No hotel found
# hawaiian paradise park - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# pierre - nearest hotel: Quality Inn
# remire-montjoly - nearest hotel: Complexe Belova
# sinop - nearest hotel: No hotel found
# joao pinheiro - nearest hotel: Lícia
# boiling springs - nearest hotel: Days Inn by Wyndham Spartanburg
# tamanrasset - nearest hotel: فندق الأمان
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# arequipa - nearest hotel: Casa Andina
# badiyah - nearest hotel: Al Areen Hotel Apartments
# morehead city - nearest hotel: Bask Hotel Big Rock Landing, Trademark Collection by Wyndham
# vila velha - nearest hotel: Hotel Prainha
# al kharijah - nearest hotel: Kharga Hotel
# sokcho - nearest hotel: Happy House Hotel
# 'ain benian - nearest hotel: Mercure Africana
# mermoz boabab - nearest hotel: La maison blanche
# wacheng - nearest hotel: No hotel found
# stephenville - nearest hotel: No hotel found
# estevan - nearest hotel: Days Inn
# nantucket - nearest hotel: No hotel found
# steamboat springs - nearest hotel: Hotel Bristol
# darwin - nearest hotel: Mantra Pantanas Darwin
# chotila - nearest hotel: Hotel India
# troy - nearest hotel: Embassy Suites Hotel
#                        City Country      Lat       Lng  Humidity  \
# 21           port elizabeth      ZA -33.9180   25.5701        58
# 32           guerrero negro      MX  27.9769 -114.0611        60
# 34              sao vicente      BR -23.9631  -46.3919        26
# 49                 hamilton      US  39.1834  -84.5333        40
# 82            pacific grove      US  36.6177 -121.9166        78
# 108               el galpon      AR -25.3807  -64.6526        68
# 113  hawaiian paradise park      US  19.5933 -154.9731        73
# 136            saint-pierre      RE -21.3393   55.4781        73
# 146                  pierre      US  44.3683 -100.3510        36
# 216         remire-montjoly      GF   4.9167  -52.2667        89
# 218                   sinop      TR  41.7711   34.8709        27
# 248           joao pinheiro      BR -17.7425  -46.1725        45
# 282         boiling springs      US  35.0465  -81.9818        40
# 289             tamanrasset      DZ  22.7850    5.5228         9
# 321           haiku-pauwela      US  20.9219 -156.3051        71
# 328                arequipa      PE -16.3989  -71.5350        16
# 355                 badiyah      OM  22.4500   58.8000        51
# 356           morehead city      US  34.7229  -76.7260        65
# 378              vila velha      BR -20.3297  -40.2925        83
# 417             al kharijah      EG  25.4514   30.5464        19
# 423                  sokcho      KR  38.2083  128.5911        36
# 442             'ain benian      DZ  36.8028    2.9219        75
# 443           mermoz boabab      SN  14.7065  -17.4758        83
# 512                 wacheng      CN  33.7833  114.5167        48
# 519            stephenville      US  32.2207  -98.2023        72
# 537                 estevan      CA  49.1334 -102.9842        38
# 549               nantucket      US  41.2835  -70.0995        76
# 556       steamboat springs      US  40.4850 -106.8317        25
# 560                  darwin      AU -12.4611  130.8418        91
# 561                 chotila      IN  22.4167   71.1833        71
# 577                    troy      US  42.6056  -83.1499        43
#
#                                             Hotel Name
# 21                                     Waterford Hotel
# 32                                   Plaza sal paraiso
# 34                                     Pousada Vitória
# 49                                   North Vista Manor
# 82                                   Pacific Grove Inn
# 108                                     No hotel found
# 113                                     No hotel found
# 136                                       Tropic Hotel
# 146                                        Quality Inn
# 216                                    Complexe Belova
# 218                                     No hotel found
# 248                                              Lícia
# 282                    Days Inn by Wyndham Spartanburg
# 289                                        فندق الأمان
# 321                           Inn At Mama's Fish House
# 328                                        Casa Andina
# 355                          Al Areen Hotel Apartments
# 356  Bask Hotel Big Rock Landing, Trademark Collect...
# 378                                      Hotel Prainha
# 417                                       Kharga Hotel
# 423                                  Happy House Hotel
# 442                                   Mercure Africana
# 443                                  La maison blanche
# 512                                     No hotel found
# 519                                     No hotel found
# 537                                           Days Inn
# 549                                     No hotel found
# 556                                      Hotel Bristol
# 560                             Mantra Pantanas Darwin
# 561                                        Hotel India
# 577                               Embassy Suites Hotel

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_add = hotel_df.hvplot.points("Lng", 
                                   "Lat", 
                                   geo = True,
                                   color = "City",
                                   alpha = 0.8,
                                   size = "Humidity",
                                   tiles = "OSM",
                                   hover_cols = ["Hotel Name", "Country"]
                                  )

# Display the map
hotel_add
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
